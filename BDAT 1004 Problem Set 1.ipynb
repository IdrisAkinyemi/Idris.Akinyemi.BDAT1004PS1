# %% [markdown]
# ## STUDENT NAME: AKINYEMI Idris Akintunde
# ## STUDENT NO: 200468633
# ## BDAT 1004 Assignment: Problem Set 1

# %% [markdown]
# ### QUESTION 1
#
# 5            | is an Integral data type
# 5.0          | is a floating data type
# '5'          | is a string data type
# 5 * 2        | is an Integral data type
# '5' * 2      | is a string data type
# '5' + '2'    | is a string data type
# 5 / 2        | is a floating data type
# 5 // 2       | is a string data type
# [5,2,1]      | is an array data type
# 5 in [1,4,6] | is an array data  type
# pi           | is a floating data type

# %% [markdown]
# ### QUESTION 2
# #### Question 2a
# ![Question%202a%20code.png](attachment:Question%202a%20code.png)
# ![Question%202a%20output.png](attachment:Question%202a%20output.png)
#
# #### Question 2b
# ![Question%202b%20code.png](attachment:Question%202b%20code.png)
# ![Question%202b%20ouput.png](attachment:Question%202b%20ouput.png)
#
# #### Question 2c
# ![Question%202c%20code.png](attachment:Question%202c%20code.png)
# ![Question%202c%20output.png](attachment:Question%202c%20output.png)
#
# #### Question 2d
# ![Question%202d%20code.png](attachment:Question%202d%20code.png)
# ![Question%202d%20output.png](attachment:Question%202d%20output.png)

# %% [markdown]
# ### QUESTION 3
# ![Question%203%20code.png](attachment:Question%203%20code.png)
# ![Question%203%20output.png](attachment:Question%203%20output.png)

# %% [markdown]
# ### QUESTION 4
# ![Question%204%20Code%20a.png](attachment:Question%204%20Code%20a.png)
# ![Question%204%20Code%20b.png](attachment:Question%204%20Code%20b.png)
# ![Question%204%20output.png](attachment:Question%204%20output.png)

# %% [markdown]
# ### QUESTION 5
# ![Question%205a%20Code.png](attachment:Question%205a%20Code.png)
# ![Question%205a%20Output%20false.png](attachment:Question%205a%20Output%20false.png)
# ![Question%205a%20Output%20true.png](attachment:Question%205a%20Output%20true.png)
# ![Question%205b%20i%20code.png](attachment:Question%205b%20i%20code.png)
# ![Question%205b%20i%20output.png](attachment:Question%205b%20i%20output.png)
# ![Question%205b%20ii%20code.png](attachment:Question%205b%20ii%20code.png)
# ![Question%205b%20ii%20output.png](attachment:Question%205b%20ii%20output.png)

# %%
# QUESTION 6a
# Sample code from https://geektechstuff.com/2018/12/12/convert-words-to-pig-latin-python/

ay = "ay" #define ay
way = "way" #define way
vowels = ("a","e","i","o","u") #assign arrays to vowels
consonants = ("b","c","d","f","g","h","j","k","l","m","n","p","q","r","s","t","y","v","x","z") #assign array to consonants
PigLatinword = input("Enter a word: ")
first_letter = PigLatinword[0] #define first_letter as the first letter of the word
first_letter = str(first_letter) #converts it to a string
first_letter = first_letter.lower() #converts it to lowercase
if first_letter in consonants:
   print(first_letter,"is a consonant")
   length_of_word = len(PigLatinword)
   getfirstletter = PigLatinword[1:length_of_word]
   pig_latin = getfirstletter + first_letter + ay
   print("The word in Pig Latin is:", pig_latin)
elif first_letter in vowels:
   print(first_letter,"is a vowel")
   pig_latin = PigLatinword + way
   print("The word in Pig Latin is:", pig_latin)
else:
   print("I dont know what", first_letter, " is")
# Out:
# Enter a word: happy
# h is a consonant
# The word in Pig Latin is: appyhay

# %%
# QUESTION 6b
# Sample code from https://geektechstuff.com/2018/12/12/convert-words-to-pig-latin-python/
ay = "ay"
way = "way"
vowels = ("a","e","i","o","u")
consonants = ("b","c","d","f","g","h","j","k","l","m","n","p","q","r","s","t","y","v","x","z")
PigLatinword = input("Enter a word: ")
first_letter = PigLatinword[0]
first_letter = str(first_letter)
first_letter = first_letter.lower()
if first_letter in consonants:
   print(first_letter,"is a consonant")
   length_of_word = len(PigLatinword)
   getfirstletter = PigLatinword[1:length_of_word]
   pig_latin = getfirstletter + first_letter + ay
   print("The word in Pig Latin is:", pig_latin)
elif first_letter in vowels:
   print(first_letter,"is a vowel")
   pig_latin = PigLatinword + way
   print("The word in Pig Latin is:", pig_latin)
else:
   print(first_letter, " is not recognised")
# Out:
# Enter a word: Enter
# e is a vowel
# The word in Pig Latin is: Enterway

# %%
#QUESTION 7
# code format idea from https://www.sanfoundry.com/python-program-count-occurrences-
#word-text-file/#:~:text=%20Python%20Program%20to%20Count%20the%20Occurrences%20of,
#are%2C%20increment%20the%20word...%204%20Exit.%20More%20
word1 = "A"
word2 = "B"
word3 = "AB"
word4 = "O"
word5 = "OO"
k = 0
k2 = 0
k3 = 0
k4 = 0
k5 = 0
with open("bloodtype1.txt", 'r') as f:
     for line in f:
        words = line.split()
        for i in words:
            if(i==word1):
                k=k+1
            if(i==word2):
                k2=k2+1
            if(i==word3):
                k3=k3+1
            if(i==word4):
                k4=k4+1
            if(i==word5):
                k5=k5+1
print("There are", (k), "patients of blood type A.")
print("There are", (k2), "patients of blood type B.")
print("There are", (k3), "patients of blood type AB.")
print("There are", (k4), "patients of blood type O.")
print("There are", (k5), "patients of blood type OO.")
# Out:
# There are 15 patients of blood type A.
# There are 1 patients of blood type B.
# There are 13 patients of blood type AB.
# There are 15 patients of blood type O.
# There are 0 patients of blood type OO.

# %%
#QUESTION 8
Currency = input("Enter the Currency to convert:")
Amount = float(input("Enter the Amount to convert:"))

if Currency == "AUD":
    rate = 1.0345157
if Currency == "CHF":
    rate = 1.0237414
if Currency == "CNY":
    rate = 0.1550176
if Currency == "DKK":
    rate = 0.1651442
if Currency == "EUR":
    rate = 1.2296544
if Currency == "GBP":
    rate = 1.5550989
if Currency == "HKD":
    rate = 0.1270207
if Currency == "INR":
    rate = 0.0177643
if Currency == "JPY":
    rate = 0.01241401
if Currency == "MXN":
    rate = 0.0751848
if Currency == "MYR":
    rate = 0.3145411
if Currency == "NOK":
    rate = 0.1677063
if Currency == "NZD":
    rate = 0.8003591
if Currency == "PHP":
    rate = 0.0233234
if Currency == "SEK":
    rate = 0.148269
if Currency == "SGD":
    rate = 0.788871
if Currency == "THB":
    rate = 0.0313789

Conversion = Amount * rate
print ("Amount in USD =; USD", Conversion)
# Out:
# Enter the Currency to convert:JPY
# Enter the Amount to convert:100
# Amount in USD =; USD 1.241401

# %% [markdown]
# ### QUESTION 8 OUTPUT
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### QUESTION 9
# #a.X = 6 + 'a' #Erroneous state error
#
# #b.List = [10, 20, 14, 25, 14, 20, 25,]
# #print (List [10]) #Index Error (Erroneous state error)
#
# #c.math.sqrt(-1.0) #Erroneous state error
#
# #d. Using an undeclared variable, such as print(x)
# #when x has not been defined = Syntax error
#
# #e.Trying to open a file that does not exist, such as
# #mistyping the file name or looking in the wrong
# #directory.  #Errorneous state error

# %% [markdown]
# ### QUESTION 10
# Do not understand the problem
